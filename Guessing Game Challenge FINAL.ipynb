# %%
from random import randint
answer = randint(1,100)
#print(answer)
counter = 1
your_guesses = [0]

your_guesses.append(int(input("What number am I thinking of between 1 and 100? ")))

while answer != your_guesses[counter] :
    
    
    if your_guesses[counter]<1 or your_guesses[counter]>100:
        print("OUT OF BOUNDS!")
        your_guesses.append(int(input("Choose a number between 1 and 100 only : ")))
        counter +=1
        
    elif counter ==1 and your_guesses[counter] in list(range(answer-10,answer)):
        print("COLD. Go up a bit!")
        your_guesses.append(int(input("What number am I thinking of ? ")))
        counter +=1
        
    elif counter ==1 and your_guesses[counter] in list(range(answer+1,answer+11)):
        print("WARM. Go down a bit!")
        your_guesses.append(int(input("What number am I thinking of ? ")))
        counter +=1
        
    elif your_guesses[counter] in your_guesses[:counter]:
        print("Hey, come on! you've already said that.")
        your_guesses.append(int(input("Try a different number : ")))
        counter +=1
        
    elif abs(your_guesses[counter]-answer)<abs(your_guesses[counter-1]-answer):
        print("WARMER!")
        your_guesses.append(int(input("What number am I thinking of? ")))
        counter +=1

    elif abs(your_guesses[counter]-answer)>abs(your_guesses[counter-1]-answer):
        print("COLDER!")
        your_guesses.append(int(input("What number am I thinking of? ")))
        counter +=1

        
        
print(f"CORRECT! You found my number! It is {answer}! And it only took you {counter} guesses.")
# Out:
# What number am I thinking of between 1 and 100? 97
# COLDER!
# What number am I thinking of? 97
# Hey, come on! you've already said that.
# Try a different number : 98
# COLDER!
# What number am I thinking of? 98
# Hey, come on! you've already said that.
# Try a different number : 99
# COLDER!
# What number am I thinking of? 91
# WARMER!
# What number am I thinking of? 93
# COLDER!
# What number am I thinking of? 90
# WARMER!
# What number am I thinking of? 89
# WARMER!
# What number am I thinking of? 85
# WARMER!
# What number am I thinking of? 80
# WARMER!
# What number am I thinking of? 76
# WARMER!
# What number am I thinking of? 68
# WARMER!
# What number am I thinking of? 60
# WARMER!
# What number am I thinking of? 55
# WARMER!
# What number am I thinking of? 50
# WARMER!
# What number am I thinking of? 45
# WARMER!
# What number am I thinking of? 40
# WARMER!
# What number am I thinking of? 30
# WARMER!
# What number am I thinking of? 20
# WARMER!
# What number am I thinking of? 10
# WARMER!
# What number am I thinking of? 8
# WARMER!
# What number am I thinking of? 5
# CORRECT! You found my number! It is 5! And it only took you 23 guesses.
